# %%
# !pip install youtube-comment-downloader
# Out:
# Collecting youtube-comment-downloader
#   Downloading youtube_comment_downloader-0.1.70-py3-none-any.whl (7.9 kB)
# Collecting dateparser (from youtube-comment-downloader)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-comment-downloader) (2.31.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateparser->youtube-comment-downloader) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser->youtube-comment-downloader) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser->youtube-comment-downloader) (2023.6.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->youtube-comment-downloader) (5.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-comment-downloader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-comment-downloader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-comment-downloader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-comment-downloader) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->dateparser->youtube-comment-downloader) (1.16.0)
# Installing collected packages: dateparser, youtube-comment-downloader
# Successfully installed dateparser-1.2.0 youtube-comment-downloader-0.1.70

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json

# %%
# get youtube video ID from csv
file_path = '/content/drive/Shareddrives/CSCE 470 Project/1000_with_video_ids1.csv'

df = pd.read_csv(file_path)
df
# take first video
# Out:
#      Rank             username  \
# 0       1              tseries
# 1       2            checkgate
# 2       3            PewDiePie
# 3       4          MrBeast6000
# 4       5    ✿ Kids Diana Show
# ..    ...                  ...
# 995   996        123 GO! Hindi
# 996   997       welovekamikaze
# 997   998  TheSyndicateProject
# 998   999           DELRECORDS
# 999  1000                 BIBI
#
#                                            Youtube Url  \
# 0    http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1    http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 2    http://youtube.com/channel/UC-lHJZR3Gqxm24_Vd_...
# 3    http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 4    http://youtube.com/channel/UCk8GzjMOrta8yxDcKf...
# ..                                                 ...
# 995  http://youtube.com/channel/UCClG8Br9HvIlgJEnP0...
# 996  http://youtube.com/channel/UCjqZeIIXmNj3WS7auJ...
# 997  http://youtube.com/channel/UC1ieoHqKW-yYgDhLHI...
# 998  http://youtube.com/channel/UChYwYTzrhfxPfJPFWR...
# 999  http://youtube.com/channel/UCF5VmU9N3sqqVe-F6E...
#
#                            Name          Category Subscribers  \
# 0                      T-Series     Music & Dance      220.1M
# 1    Cocomelon - Nursery Rhymes         Education      138.6M
# 2                     PewDiePie         Animation      111.4M
# 3                       MrBeast  Video gamesHumor       98.4M
# 4             ✿ Kids Diana Show     AnimationToys       97.5M
# ..                          ...               ...         ...
# 995               123 GO! Hindi               NaN        9.8M
# 996              welovekamikaze               NaN        9.7M
# 997                   Syndicate       Video games        9.7M
# 998                 DEL Records     Music & Dance        9.7M
# 999                        BIBI   MoviesAnimation        9.7M
#
#     Audience Country Avg. Views Avg. Likes Avg. Comments     Video ID
# 0              India      52.7K       1.7K           108  0Jwg55gK7Ok
# 1                NaN      14.5M      79.5K         'N/A'  650oOOyEKG4
# 2      United States       3.6M       244K         11.4K  5puX_BVuVAA
# 3      United States      36.7M       2.1M         78.5K  AjZDwxt7S8w
# 4                NaN      18.1M      71.8K         'N/A'  JdUzB4eEhoc
# ..               ...        ...        ...           ...          ...
# 995            India     829.5K       5.9K            44          NaN
# 996              NaN       2.5K         68             6          NaN
# 997    United States      56.6K       2.3K           371          NaN
# 998           Mexico     724.6K      23.2K           354          NaN
# 999              NaN      28.2K       3.7K           131          NaN
#
# [1000 rows x 11 columns]

# %%
row1 = df.at[0,'Video ID']
row1
url = 'https://www.youtube.com/watch?v=' + row1
url
# Out:
# 'https://www.youtube.com/watch?v=0Jwg55gK7Ok'

# %%
from itertools import islice
from youtube_comment_downloader import *
downloader = YoutubeCommentDownloader()


comments = downloader.get_comments_from_url(url, sort_by=SORT_BY_POPULAR)
comments_list = []
for comment in islice(comments, 5):
    comments_list.append(comment)
for i in comments_list:
  print(i['text'])
# Out:
# Class 11th wale attendance lagao 😁 jaldi se
# LET'S VOTE FOR SAYING YES To  T-SHIRISH FOR 24 HOURS PLEASE
# Tulsi is like Tulsi........
# Medicine for ear...... melodies ❤
# nice
# 🎉
